# %%
import pandas as pd
dir = "D:\pandas-master\pokemon_data.xlsx"
data = pd.read_excel(dir)
print(data.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
data['Type 2'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Type 2'>

# %%
data.loc[:, 'Name'].head(3)
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object

# %%
data.iloc[:,1].head(3)
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Name, dtype: object

# %%
dir1= 'D:\pandas-master\pokemon1.xlsx'
data1= pd.read_excel(dir1)
data1.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 349  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 350  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 351  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 349      130     70           6       True
# 350      130     80           6       True
# 351       90     70           6       True

# %%
dsjoin= pd.merge(data,data1, on='Name', how="inner")
dsjoin.head(2)
# Out:
# Empty DataFrame
# Columns: [#_x, Name, Type 1_x, Type 2_x, HP_x, Attack_x, Defense_x, Sp. Atk_x, Sp. Def_x, Speed_x, Generation_x, Legendary_x, #_y, Type 1_y, Type 2_y, HP_y, Attack_y, Defense_y, Sp. Atk_y, Sp. Def_y, Speed_y, Generation_y, Legendary_y]
# Index: []
#
# [0 rows x 23 columns]

# %%
df=pd.concat([data,data1],axis=0)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 347  719                Diancie     Rock   Fairy  50     100      150
# 348  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 349  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 350  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 351  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df=df.reset_index()
df=df.drop(['index'],axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 792  719                Diancie     Rock   Fairy  50     100      150
# 793  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 794  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 795  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 796  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#def function(x):
#    return x/5
#data['Speed']=data['Speed'].map(function)
#data['Speed'].head(3)

# %%
data[['HP','Speed']]=data[['HP','Speed']].apply(lambda x: x/5)
data[['HP','Speed']].head(3)
# Out:
#      HP  Speed
# 0   9.0    9.0
# 1  12.0   12.0
# 2  16.0   16.0

# %%
new_df1= data[(data['Type 1'] == 'Grass') & (data['Type 2'] == 'Poison') & (data['HP'] > 70)]
new_df1
new_df1.to_excel('D:\pandas-master\Filtered.xlsx', index=False)
